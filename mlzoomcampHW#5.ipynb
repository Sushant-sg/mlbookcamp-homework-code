# %%
# !pip install pipenv
# Out:
# ...
#      ---------------------------------------- 3.3/3.3 MB 2.9 MB/s eta 0:00:00
# ...

# %%
# !pip list
# Out:
# Package              Version
# -------------------- -----------
# anyio                3.6.1
# argon2-cffi          21.3.0
# argon2-cffi-bindings 21.2.0
# asttokens            2.0.5
# attrs                22.1.0
# Babel                2.10.3
# backcall             0.2.0
# beautifulsoup4       4.11.1
# bleach               5.0.1
# certifi              2022.5.18.1
# cffi                 1.15.1
# charset-normalizer   2.0.12
# cheap-repr           0.5.1
# click                8.0.4
# colorama             0.4.4
# cycler               0.11.0
# debugpy              1.5.1
# decorator            5.1.0
# defusedxml           0.7.1
# distlib              0.3.4
# entrypoints          0.3
# executing            0.8.3
# fastjsonschema       2.16.1
# filelock             3.7.1
# Flask                2.0.3
# fonttools            4.37.2
# heartrate            0.2.2
# idna                 3.3
# ipykernel            6.6.0
# ipython              7.30.1
# ipython-genutils     0.2.0
# ...

# %%
# !pipenv --version
# Out:
# pipenv, version 2022.10.4

# %%
# !pipenv install scikit-learn
# Out:
# Installing scikit-learn...
# Installing dependencies from Pipfile.lock (fb8ea6)...
# To activate this project's virtualenv, run pipenv shell.
# Alternatively, run a command inside the virtualenv with pipenv run.
# Creating a virtualenv for this project...
#
# Pipfile: C:\Users\user\Pipfile
#
# Using C:/Users/user/AppData/Local/Programs/Python/Python310/python.exe (3.10.1) to create virtualenv...
#
#
# [    ] Creating virtual environment..
# [=   ] Creating virtual environment..
# [==  ] Creating virtual environment..
# [=== ] Creating virtual environment..
# [ ===] Creating virtual environment..
# [  ==] Creating virtual environment..
# [   =] Creating virtual environment..
# [    ] Creating virtual environment..
# [   =] Creating virtual environment..
# [  ==] Creating virtual environment..
# [ ===] Creating virtual environment..
# [====] Creating virtual environment..
# [=== ] Creating virtual environment..
# [==  ] Creating virtual environment..
# ...

# %%
PREFIX=https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/course-zoomcamp/cohorts/2022/0o5-deployment/homework
# !wget -p r'H:\MLbookcamp\Homework#5' $PREFIX/model1.bin
# !wget -p r'H:\MLbookcamp\Homework#5' $PREFIX/dv.bin
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_6408/3612969690.py", line 1
#     PREFIX=https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/course-zoomcamp/cohorts/2022/0o5-deployment/homework
#                 ^
# SyntaxError: invalid syntax

# %%
import pickle

def load(filename):
    with open(filename, 'rb') as f_in:
        return pickle.load(f_in)


dv = load(r'H:\MLbookcamp\Homework#5\dv.bin')
model = load(r'H:\MLbookcamp\Homework#5\model1.bin')

customer = {"reports": 0, "share": 0.001694, "expenditure": 0.12, "owner": "yes"}

X = dv.transform([customer])
y_pred = model.predict_proba(X)[0, 1]

print(y_pred)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DictVectorizer from version 1.0.2 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 0.16213414434326598
# C:\Users\user\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator LogisticRegression from version 1.0.2 when using version 1.1.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# !pip install waitress
# Out:
# ...
#      ---------------------------------------- 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from flask import Flask
from flask import request
from flask import jsonify

import pickle

def load(filename):
    with open(filename, 'rb') as f_in:
        return pickle.load(f_in)


dv = load(r'H:\MLbookcamp\Homework#5\dv.bin')
model = load(r'H:\MLbookcamp\Homework#5\model1.bin')

app = Flask('churn')

@app.route('/predict', methods=['POST'])
def predict():
    customer = request.get_json()

    X = dv.transform([customer])
    y_pred = model.predict_proba(X)[0, 1]
    churn = y_pred >= 0.5

    result = {
        'churn_probability': float(y_pred),
        'churn': bool(churn)
    }

    return jsonify(result)


if __name__ == "__main__":
    app.run(debug=True, host='0.0.0.0', port=9696)
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6408/4139868405.py in <module>
#      32
#      33 if __name__ == "__main__":
# ---> 34     app.run(debug=True, host='0.0.0.0', port=9696)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\flask\app.py in run(self, host, port, debug, load_dotenv, **options)
#     918
#     919         try:
# --> 920             run_simple(t.cast(str, host), port, self, **options)
#     921         finally:
#     922             # reset the first request information if the development server
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\werkzeug\serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, exclude_patterns, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
# ...

# %%
import requests

url = "http://localhost:9696/predict"

customer =  {"reports": 0, "share": 0.245, "expenditure": 3.438, "owner": "yes"}
respose = requests.post(url, json=customer).json()


print(respose)
# Out:
# {'churn': True, 'churn_probability': 0.9282218018527452}
